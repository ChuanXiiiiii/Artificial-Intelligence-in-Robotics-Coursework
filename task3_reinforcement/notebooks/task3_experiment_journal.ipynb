# %% [markdown]
# # Task3 Experiment Journal\n
# \n
# SEMTM0016 Task3 RL logbook (Random vs DQN vs PPO, Reward A/B, seeds 42/123/2026/9/20).

# %% [markdown]
# ## Run Contract
# - Environment baseline: SEMTM0016_DungeonMazeWorld-main
# - Methods: Random, DQN, PPO
# - Reward schemes: A sparse, B dense heuristic, C potential, E2 Path Shaping
# - Seeds: 42, 123, 2026, 9, 20
# - Curriculum Learning: Radius-based incremental training (Fast & Master)
# - Timesteps per method/seed: 1,000,000 (standard), 2,000,000 (master)

# %%
from pathlib import Path\n
import pandas as pd\n
\n
root = Path('..').resolve()\n
tables = root / 'outputs' / 'tables'\n
summary_path = tables / 'metrics_multi_seed_summary.csv'\n
summary_path

# %%
if summary_path.exists():\n
    display(pd.read_csv(summary_path))\n
else:\n
    print('Run src/run_task3_multi_seed.sh first to generate summary tables.')
